# %% [markdown]
# ### Exercise
# * Make a function that only accept positive values.
# * raise exceptions (Hint: use ValueError).
# * Use `try - except` to handle the error.

# %%
def I_only_accept_positive(num):
# Out:
#   File "<ipython-input-13-cbfdb3cf0030>", line 2
#
#     ^
# IndentationError: expected an indented block

# %%
def I_only_accept_positive(num):
# Out:
#   File "<ipython-input-14-ff1db2a14a9a>", line 1
#     def I_only_accept_positive(num):
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# * what if we call it directely?
